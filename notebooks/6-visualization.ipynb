# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import json
import os
import pandas as pd
from tqdm import tqdm
import shutil
import sys
root_path = os.path.abspath("..")
data_path = "/data/MHL/bepro/raw"
sys.path.append(root_path)

from preprocess_bepro import load_single_json, create_team_dataframe, create_event_dataframe, create_tracking_dataframe
from visualization import plot_single_frame_positions, plot_window_frame_positions

# %%
match_id_lst = os.listdir(data_path)
match_id = "126315"

match_path = f"{data_path}/{match_id}"
os.listdir(match_path)
# Out:
# ['126315_2_event_data.json',
#  '126315_metadata.json',
#  '126315_1_frame_data.jsonl',
#  '126315_2_frame_data.jsonl',
#  '126315_1_event_data.json']

# %%
# Check Metadata
meta_data_path = f"{match_path}/{match_id}_metadata.json"
meta_data = load_single_json(meta_data_path)
for key, value in meta_data.items():
    print(f"{key} : {value}")
# Out:
# match_id : 126315
# match_title : 김천 상무 프로축구단 vs 광주FC
# match_datetime : 2024-04-06T16:30:00+0900
# match_full_time : 5400000
# match_extra_time : None
# periods : [{'period_name': '1st Half', 'period_order': 0, 'period_match_duration': 2700000}, {'period_name': '2nd Half', 'period_order': 1, 'period_match_duration': 2700000}]
# home_team : {'team_id': 2353, 'team_name': '김천 상무 프로축구단', 'team_name_en': 'Gimcheon Sangmu', 'players': [{'player_id': 356626, 'team_id': 2353, 'shirt_number': '17', 'full_name': '김준홍', 'full_name_en': 'Joonhong Kim', 'initial_position_name': 'GK', 'is_starting': True}, {'player_id': 500576, 'team_id': 2353, 'shirt_number': '25', 'full_name': '박승욱', 'full_name_en': 'Seunguk Park', 'initial_position_name': 'CB', 'is_starting': True}, {'player_id': 500569, 'team_id': 2353, 'shirt_number': '15', 'full_name': '김봉수', 'full_name_en': 'Bongsoo Kim', 'initial_position_name': 'CB', 'is_starting': True}, {'player_id': 500562, 'team_id': 2353, 'shirt_number': '23', 'full_name': '박수일', 'full_name_en': 'Suil Park', 'initial_position_name': 'RB', 'is_starting': True}, {'player_id': 356609, 'team_id': 2353, 'shirt_number': '88', 'full_name': '박민규', 'full_name_en': 'Mingyu Park', 'initial_position_name': 'LB', 'is_starting': True}, {'player_id': 356624, 'team_id': 2353, 'shirt_number': '14', 'full_name': '강현묵', 'full_name_en': 'Hyeonmuk Kang', 'initial_position_name': 'CAM', 'is_starting': True}, {'player_id': 356616, 'team_id': 2353, 'shirt_number': '5', 'full_name': '김동현', 'full_name_en': 'Dong Hyun Kim', 'initial_position_name': 'CM', 'is_starting': True}, {'player_id': 356618, 'team_id': 2353, 'shirt_number': '4', 'full_name': '김진규', 'full_name_en': 'Jingyu Kim', 'initial_position_name': 'CM', 'is_starting': True}, {'player_id': 500580, 'team_id': 2353, 'shirt_number': '22', 'full_name': '김대원', 'full_name_en': 'Daewon Kim', 'initial_position_name': 'RW', 'is_starting': True}, {'player_id': 356615, 'team_id': 2353, 'shirt_number': '32', 'full_name': '정치인', 'full_name_en': 'Chiin Jeong', 'initial_position_name': 'LW', 'is_starting': True}, {'player_id': 500583, 'team_id': 2353, 'shirt_number': '18', 'full_name': '유강현', 'full_name_en': 'Kanghyun Yu', 'initial_position_name': 'CF', 'is_starting': True}, {'player_id': 500558, 'team_id': 2353, 'shirt_number': '21', 'full_name': '김동헌', 'full_name_en': 'Dongheon Kim', 'initial_position_name': None, 'is_starting': False}, {'player_id': 500561, 'team_id': 2353, 'shirt_number': '20', 'full_name': '김민덕', 'full_name_en': 'Mindeok Kim', 'initial_position_name': 'CB', 'is_starting': False}, {'player_id': 356610, 'team_id': 2353, 'shirt_number': '8', 'full_name': '윤종규', 'full_name_en': 'Jonggyu Yun', 'initial_position_name': None, 'is_starting': False}, {'player_id': 356614, 'team_id': 2353, 'shirt_number': '77', 'full_name': '김태현', 'full_name_en': 'Taehyeon Kim', 'initial_position_name': None, 'is_starting': False}, {'player_id': 500577, 'team_id': 2353, 'shirt_number': '28', 'full_name': '이진용', 'full_name_en': 'Jinyong Lee', 'initial_position_name': 'CM', 'is_starting': False}, {'player_id': 356621, 'team_id': 2353, 'shirt_number': '2', 'full_name': '구본철', 'full_name_en': 'BOONCHEUL GOO', 'initial_position_name': None, 'is_starting': False}, {'player_id': 356611, 'team_id': 2353, 'shirt_number': '3', 'full_name': '김현욱', 'full_name_en': 'Hyeonuk Kim', 'initial_position_name': 'LW', 'is_starting': False}, {'player_id': 356623, 'team_id': 2353, 'shirt_number': '26', 'full_name': '김민준', 'full_name_en': 'Minjun Kim', 'initial_position_name': 'RW', 'is_starting': False}, {'player_id': 356622, 'team_id': 2353, 'shirt_number': '99', 'full_name': '이중민', 'full_name_en': 'Jungmin Lee', 'initial_position_name': 'CF', 'is_starting': False}]}
# away_team : {'team_id': 4648, 'team_name': '광주FC', 'players': [{'player_id': 250099, 'team_id': 4648, 'shirt_number': '21', 'full_name': '이준', 'full_name_en': 'Jun Lee', 'initial_position_name': 'GK', 'is_starting': True}, {'player_id': 145701, 'team_id': 4648, 'shirt_number': '3', 'full_name': '이민기', 'full_name_en': 'Mingi Lee', 'initial_position_name': 'LB', 'is_starting': True}, {'player_id': 500133, 'team_id': 4648, 'shirt_number': '4', 'full_name': '포포비치', 'full_name_en': 'Alexandar Popovic', 'initial_position_name': 'CB', 'is_starting': True}, {'player_id': 62365, 'team_id': 4648, 'shirt_number': '6', 'full_name': '안영규', 'full_name_en': 'Youngkyu Ahn', 'initial_position_name': 'CB', 'is_starting': True}, {'player_id': 500140, 'team_id': 4648, 'shirt_number': '27', 'full_name': '김진호', 'full_name_en': 'Jinho Kim', 'initial_position_name': 'RB', 'is_starting': True}, {'player_id': 500135, 'team_id': 4648, 'shirt_number': '11', 'full_name': '가브리엘', 'full_name_en': 'Gabriel', 'initial_position_name': 'RM', 'is_starting': True}, {'player_id': 360389, 'team_id': 4648, 'shirt_number': '24', 'full_name': '이강현', 'full_name_en': 'Kang Hyun Lee', 'initial_position_name': 'CM', 'is_starting': True}, {'player_id': 500139, 'team_id': 4648, 'shirt_number': '30', 'full_name': '최경록', 'full_name_en': 'Kyongrok Choi', 'initial_position_name': 'CM', 'is_starting': True}, {'player_id': 500136, 'team_id': 4648, 'shirt_number': '88', 'full_name': '문민서', 'full_name_en': 'Minseo Moon', 'initial_position_name': 'LM', 'is_starting': True}, {'player_id': 77414, 'team_id': 4648, 'shirt_number': '10', 'full_name': '이희균', 'full_name_en': 'Huigyun Lee', 'initial_position_name': 'CF', 'is_starting': True}, {'player_id': 250102, 'team_id': 4648, 'shirt_number': '20', 'full_name': '이건희', 'full_name_en': 'Kunhee Lee', 'initial_position_name': 'CF', 'is_starting': True}, {'player_id': 250105, 'team_id': 4648, 'shirt_number': '31', 'full_name': '노희동', 'full_name_en': 'Heedong No', 'initial_position_name': None, 'is_starting': False}, {'player_id': 62386, 'team_id': 4648, 'shirt_number': '13', 'full_name': '두현석', 'full_name_en': 'Hyeonseok Doo', 'initial_position_name': None, 'is_starting': False}, {'player_id': 360165, 'team_id': 4648, 'shirt_number': '23', 'full_name': '김경재', 'full_name_en': 'Gyeongjae Kim', 'initial_position_name': 'CB', 'is_starting': False}, {'player_id': 250101, 'team_id': 4648, 'shirt_number': '14', 'full_name': '정호연', 'full_name_en': 'Hoyeon Jeong', 'initial_position_name': 'CM', 'is_starting': False}, {'player_id': 359624, 'team_id': 4648, 'shirt_number': '44', 'full_name': '아사니', 'full_name_en': 'Jasir Asani', 'initial_position_name': 'CM', 'is_starting': False}, {'player_id': 500142, 'team_id': 4648, 'shirt_number': '55', 'full_name': '박태준', 'full_name_en': 'Taejun Park', 'initial_position_name': None, 'is_starting': False}, {'player_id': 500134, 'team_id': 4648, 'shirt_number': '9', 'full_name': '빅톨', 'full_name_en': 'Joao Victo Magno', 'initial_position_name': 'CF', 'is_starting': False}, {'player_id': 500137, 'team_id': 4648, 'shirt_number': '17', 'full_name': '정지용', 'full_name_en': 'Jiyong Jeong', 'initial_position_name': 'CF', 'is_starting': False}, {'player_id': 369783, 'team_id': 4648, 'shirt_number': '77', 'full_name': '오후성', 'full_name_en': 'Huseong Oh', 'initial_position_name': None, 'is_starting': False}]}
# match_result : {'home_team_score': 2, 'away_team_score': 1}
# fps : 30
# ground_width : 105
# ground_height : 68

# %%
teams_dict = create_team_dataframe(meta_data['home_team'], meta_data['away_team'])
teams_dict['Home']
# Out:
#            player position  team jID     pID   tID  xID
# 0    Joonhong Kim       GK  Home  17  356626  2353    0
# 1    Seunguk Park       CB  Home  25  500576  2353    1
# 2     Bongsoo Kim       CB  Home  15  500569  2353    2
# 3       Suil Park       RB  Home  23  500562  2353    3
# 4     Mingyu Park       LB  Home  88  356609  2353    4
# 5   Hyeonmuk Kang      CAM  Home  14  356624  2353    5
# 6   Dong Hyun Kim       CM  Home   5  356616  2353    6
# 7      Jingyu Kim       CM  Home   4  356618  2353    7
# 8      Daewon Kim       RW  Home  22  500580  2353    8
# 9     Chiin Jeong       LW  Home  32  356615  2353    9
# 10    Kanghyun Yu       CF  Home  18  500583  2353   10
# 11   Dongheon Kim     None  Home  21  500558  2353   11
# 12    Mindeok Kim       CB  Home  20  500561  2353   12
# 13    Jonggyu Yun     None  Home   8  356610  2353   13
# 14   Taehyeon Kim     None  Home  77  356614  2353   14
# 15    Jinyong Lee       CM  Home  28  500577  2353   15
# 16  BOONCHEUL GOO     None  Home   2  356621  2353   16
# 17    Hyeonuk Kim       LW  Home   3  356611  2353   17
# 18     Minjun Kim       RW  Home  26  356623  2353   18
# 19    Jungmin Lee       CF  Home  99  356622  2353   19

# %%
event_df = create_event_dataframe(match_path)
event_df.head()
# Out:
#   period_type period_name  period_order  period_duration  period_start_time  \
# 0        Half    1st Half             0          2700000                  0
# 1        Half    1st Half             0          2700000                  0
# 2        Half    1st Half             0          2700000                  0
# 3        Half    1st Half             0          2700000                  0
# 4        Half    1st Half             0          2700000                  0
#
#    event_time        team_name player_shirt_number    player_name  \
# 0        2167       Gwangju FC                  24  Kang Hyun Lee
# 1        3000  Gimcheon Sangmu                  18    Kanghyun Yu
# 2        3000       Gwangju FC                  20     Kunhee Lee
# 3        3500       Gwangju FC                  11        Gabriel
# 4        3967       Gwangju FC                   6   Youngkyu Ahn
#
#                                               events         x         y  \
# 0  [{'event_name': 'Passes', 'property': {'Outcom...  0.500800  0.527100
# 1  [{'name': 'VHIR', 'property': {'duration': 200...  0.533551  0.654105
# 2  [{'name': 'VHIR', 'property': {'duration': 250...  0.482749  0.274083
# 3  [{'name': 'VHIR', 'property': {'duration': 150...  0.467462  0.754444
# 4  [{'event_name': 'Passes Received', 'property':...  0.657600  0.689500
#
#        to_x      to_y attack_direction
# 0  0.657600  0.689500             LEFT
# 1  0.637543  0.683009            RIGHT
# 2  0.354669  0.275258             LEFT
# 3  0.398143  0.716478             LEFT
# 4       NaN       NaN             LEFT

# %%
match_path = f"{data_path}/{match_id}"

tracking_df = create_tracking_dataframe(match_path, meta_data, teams_dict)
tracking_df.head()
# Out:
#   game_id  period_id              timestamp  frame_id ball_state  \
# 0  126315        1.0 0 days 00:00:02.200000        55      alive
# 1  126315        1.0 0 days 00:00:02.200000        55      alive
# 2  126315        1.0 0 days 00:00:02.200000        55      alive
# 3  126315        1.0 0 days 00:00:02.200000        55      alive
# 4  126315        1.0 0 days 00:00:02.200000        55      alive
#
#   ori_ball_owning_team_id        x        y    z        vx  ...         v  \
# 0                    4648  10.6651 -15.7343  0.0  0.010984  ...  0.017269
# 1                    4648  49.4965  -1.8148  0.0 -0.000366  ...  0.010506
# 2                    4648   0.2787 -15.3854  0.0 -0.789224  ...  1.062552
# 3                    4648 -16.2408  16.2649  0.0 -0.457413  ...  0.469734
# 4                    4648   0.0131  21.5149  0.0  0.946555  ...  1.061619
#
#          ax        ay   az         a      id  team_id position_name  \
# 0  0.095604  0.331254  0.0  0.344774  145701     4648            LB
# 1 -0.009143  0.157149  0.0  0.157415  250099     4648            GK
# 2 -1.959916 -0.736736  0.0  2.093813  250102     4648            CF
# 3  0.269950  0.664216  0.0  0.716976  356609     2353            LB
# 4  0.088101 -6.456073  0.0  6.000000  356615     2353            LW
#
#   ball_owning_team_id is_ball_carrier
# 0                4648           False
# 1                4648           False
# 2                4648           False
# 3                4648           False
# 4                4648           False
#
# [5 rows x 22 columns]

# %%
tracking_df[tracking_df['id']==tracking_df['id'].unique()[0]]
# Out:
#         game_id  period_id              timestamp  frame_id ball_state  \
# 0        126315        1.0 0 days 00:00:02.200000        55      alive
# 23       126315        1.0 0 days 00:00:02.240000        56      alive
# 46       126315        1.0 0 days 00:00:02.280000        57      alive
# 69       126315        1.0 0 days 00:00:02.320000        58      alive
# 92       126315        1.0 0 days 00:00:02.360000        59      alive
# ...         ...        ...                    ...       ...        ...
# 3564273  126315        2.0 0 days 01:40:50.920000    151273      alive
# 3564295  126315        2.0 0 days 01:40:50.960000    151274      alive
# 3564317  126315        2.0        0 days 01:40:51    151275      alive
# 3564339  126315        2.0 0 days 01:40:51.040000    151276      alive
# 3564361  126315        2.0 0 days 01:40:51.080000    151277      alive
#
#         ori_ball_owning_team_id          x          y    z        vx  ...  \
# 0                          4648  10.665100 -15.734300  0.0  0.010984  ...
# 23                         4648  10.665717 -15.734255  0.0  0.016251  ...
# 46                         4648  10.666505 -15.732979  0.0  0.022334  ...
# 69                         4648  10.667575 -15.730124  0.0  0.029416  ...
# 92                         4648  10.669050 -15.725782  0.0  0.036577  ...
# ...                         ...        ...        ...  ...       ...  ...
# 3564273                    4648 -20.731968  -6.391946  0.0 -2.646419  ...
# 3564295                    4648 -20.839116  -6.282338  0.0 -2.655175  ...
# 3564317                    4648 -20.943300  -6.177100  0.0 -2.656859  ...
# 3564339                    4648 -21.050660  -6.070004  0.0 -2.658542  ...
# 3564361                    4648 -21.157549  -5.964971  0.0 -2.660226  ...
#
#                 v        ax        ay   az         a      id  team_id  \
# 0        0.017269  0.095604  0.331254  0.0  0.344774  145701     4648
# 23       0.034488  0.131674  0.427366  0.0  0.447191  145701     4648
# 46       0.056069  0.152096  0.525216  0.0  0.546795  145701     4648
# 69       0.084696  0.177049  0.699868  0.0  0.721916  145701     4648
# 92       0.120969  0.179007  0.897095  0.0  0.914780  145701     4648
# ...           ...       ...       ...  ...       ...     ...      ...
# 3564273  3.795127  0.039699 -0.576735  0.0  0.578100  145701     4648
# 3564295  3.789690 -0.218904 -0.404009  0.0  0.459503  145701     4648
# 3564317  3.772271 -0.042088 -0.653422  0.0  0.654776  145701     4648
# 3564339  3.754953 -0.042088 -0.653422  0.0  0.654776  145701     4648
# 3564361  3.737739 -0.042088 -0.653422  0.0  0.654776  145701     4648
#
#         position_name ball_owning_team_id is_ball_carrier
# 0                  LB                4648           False
# 23                 LB                4648           False
# 46                 LB                4648           False
# 69                 LB                4648           False
# 92                 LB                4648           False
# ...               ...                 ...             ...
# 3564273            LB                4648           False
# 3564295            LB                4648           False
# 3564317            LB                4648           False
# 3564339            LB                4648           False
# 3564361            LB                4648           False
#
# [156764 rows x 22 columns]

# %%
plot_single_frame_positions(tracking_df, period_id=1, frame_idx=291-50, home_team_info=teams_dict['Home'], away_team_info=teams_dict['Away'])
