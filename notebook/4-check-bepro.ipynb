# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import json
import os
import pandas as pd
from tqdm import tqdm
root_path = "/home/work/data/MHL/bepro"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
match_id_lst = [153381, 153387]
match_id = match_id_lst[0]

match_path = f"{root_path}/{match_id}"
os.listdir(match_path)
# Out:
# ['153381_2_frame_data.jsonl',
#  '153381_1_frame_data.jsonl',
#  '153381_event',
#  '153381_metadata.json']

# %%
def load_single_json(file_path):
    """
    Loads and parses a single JSON file from the specified path.

    Args:
        file_path (str): The path to the JSON file to load.

    Returns:
        dict or list or None: The parsed Python object on success.
                              Returns None if the file is not found or
                              is not valid JSON.
    """
    try:
        # Open the file in read mode ('r') with UTF-8 encoding.
        # Using 'with' ensures the file is automatically closed after use.
        with open(file_path, 'r', encoding='utf-8') as f:
            # json.load() parses the JSON data from the file object.
            data = json.load(f)
            print(f"Successfully loaded file: '{file_path}'")
            return data
    except FileNotFoundError:
        print(f"Error: File not found at '{file_path}'")
        return None
    except json.JSONDecodeError:
        print(f"Error: Could not decode JSON from '{file_path}'. Check format.")
        return None
    except Exception as e:
        print(f"An unexpected error occurred while reading '{file_path}': {e}")
        return None

# %%
# Check Metadata

meta_data_path = f"{match_path}/{match_id}_metadata.json"
meta_data = load_single_json(meta_data_path)
for key, value in meta_data.items():
    print(f"{key} : {value}")
# Out:
# Successfully loaded file: '/home/work/data/MHL/bepro/153381/153381_metadata.json'
# match_id : 153381
# match_title : 수원FC vs 강원FC
# match_datetime : 2024-11-09T16:30:00+0900
# match_full_time : 5400000
# match_extra_time : None
# periods : [{'period_name': '1st Half', 'period_order': 0, 'period_match_duration': 2700000}, {'period_name': '2nd Half', 'period_order': 1, 'period_match_duration': 2700000}]
# home_team : {'team_id': 4220, 'team_name': '수원FC', 'team_name_en': 'Suwon FC', 'players': [{'player_id': 500530, 'team_id': 4220, 'shirt_number': '10', 'full_name': '지동원', 'full_name_en': 'Dongwon Ji', 'initial_position_name': 'CF', 'is_starting': True}, {'player_id': 77715, 'team_id': 4220, 'shirt_number': '24', 'full_name': '김주엽', 'full_name_en': 'Ju Yeop Kim', 'initial_position_name': None, 'is_starting': False}, {'player_id': 500547, 'team_id': 4220, 'shirt_number': '15', 'full_name': '김태한', 'full_name_en': 'Taehan Kim', 'initial_position_name': 'CB', 'is_starting': True}, {'player_id': 500552, 'team_id': 4220, 'shirt_number': '13', 'full_name': '안준수', 'full_name_en': 'Joon Soo Ahn', 'initial_position_name': 'GK', 'is_starting': True}, {'player_id': 354820, 'team_id': 4220, 'shirt_number': '30', 'full_name': '이현용', 'full_name_en': 'Hyunyong Lee', 'initial_position_name': 'CB', 'is_starting': True}, {'player_id': 500540, 'team_id': 4220, 'shirt_number': '26', 'full_name': '장영우', 'full_name_en': 'Young Woo Jang', 'initial_position_name': None, 'is_starting': False}, {'player_id': 532196, 'team_id': 4220, 'shirt_number': '71', 'full_name': '한교원', 'full_name_en': 'Gyowon Han', 'initial_position_name': 'RW', 'is_starting': True}, {'player_id': 500543, 'team_id': 4220, 'shirt_number': '4', 'full_name': '조준현', 'full_name_en': 'Yoonho Jo', 'initial_position_name': 'RWB', 'is_starting': False}, {'player_id': 503230, 'team_id': 4220, 'shirt_number': '39', 'full_name': '하정우', 'full_name_en': 'Jungwoo Ha', 'initial_position_name': None, 'is_starting': False}, {'player_id': 532195, 'team_id': 4220, 'shirt_number': '99', 'full_name': '정민기', 'full_name_en': 'Minki Jeong', 'initial_position_name': None, 'is_starting': False}, {'player_id': 500534, 'team_id': 4220, 'shirt_number': '7', 'full_name': '정승원', 'full_name_en': 'Seungwon Jeong', 'initial_position_name': 'CM', 'is_starting': True}, {'player_id': 500539, 'team_id': 4220, 'shirt_number': '44', 'full_name': '정승배', 'full_name_en': 'Seungbae Jung', 'initial_position_name': 'LW', 'is_starting': False}, {'player_id': 354812, 'team_id': 4220, 'shirt_number': '14', 'full_name': '윤빛가람', 'full_name_en': 'Bitgaram Yoon', 'initial_position_name': 'CDM', 'is_starting': True}, {'player_id': 354809, 'team_id': 4220, 'shirt_number': '3', 'full_name': '박철우', 'full_name_en': 'Cheolwoo Park', 'initial_position_name': 'LB', 'is_starting': True}, {'player_id': 500549, 'team_id': 4220, 'shirt_number': '70', 'full_name': '안데르손', 'full_name_en': 'Anderson Oliveira', 'initial_position_name': 'LW', 'is_starting': True}, {'player_id': 529744, 'team_id': 4220, 'shirt_number': '22', 'full_name': '노경호', 'full_name_en': 'Gyeongho Noh', 'initial_position_name': 'CM', 'is_starting': True}, {'player_id': 500554, 'team_id': 4220, 'shirt_number': '77', 'full_name': '강상윤', 'full_name_en': 'Sangyoon Kang', 'initial_position_name': 'CM', 'is_starting': False}, {'player_id': 287282, 'team_id': 4220, 'shirt_number': '88', 'full_name': '이용', 'full_name_en': 'Yong Lee', 'initial_position_name': 'RB', 'is_starting': True}, {'player_id': 188185, 'team_id': 4220, 'shirt_number': '21', 'full_name': '곽윤호', 'full_name_en': 'Yunho Kwak', 'initial_position_name': None, 'is_starting': False}, {'player_id': 252492, 'team_id': 4220, 'shirt_number': '20', 'full_name': '황순민', 'full_name_en': 'Soonmin Hwang', 'initial_position_name': 'LWB', 'is_starting': False}]}
# away_team : {'team_id': 4643, 'team_name': '강원FC', 'players': [{'player_id': 412017, 'team_id': 4643, 'shirt_number': '10', 'full_name': '가브리엘', 'full_name_en': 'Vitor Gabriel', 'initial_position_name': 'CF', 'is_starting': True}, {'player_id': 145673, 'team_id': 4643, 'shirt_number': '2', 'full_name': '김영빈', 'full_name_en': 'Youngbin Kim', 'initial_position_name': None, 'is_starting': False}, {'player_id': 529741, 'team_id': 4643, 'shirt_number': '9', 'full_name': '코바체비치', 'full_name_en': 'Franko Kovačević', 'initial_position_name': 'CF', 'is_starting': False}, {'player_id': 528959, 'team_id': 4643, 'shirt_number': '15', 'full_name': '진준서', 'full_name_en': 'Junseo Jin', 'initial_position_name': 'RB', 'is_starting': False}, {'player_id': 408792, 'team_id': 4643, 'shirt_number': '74', 'full_name': '강투지', 'full_name_en': 'Marko Tuci', 'initial_position_name': 'CB', 'is_starting': True}, {'player_id': 343587, 'team_id': 4643, 'shirt_number': '17', 'full_name': '유인수', 'full_name_en': 'Insoo Yu', 'initial_position_name': 'LW', 'is_starting': True}, {'player_id': 500115, 'team_id': 4643, 'shirt_number': '13', 'full_name': '이기혁', 'full_name_en': 'Gihyuk Lee', 'initial_position_name': 'CB', 'is_starting': True}, {'player_id': 500117, 'team_id': 4643, 'shirt_number': '22', 'full_name': '이상헌', 'full_name_en': 'Sangheon Lee', 'initial_position_name': 'CAM', 'is_starting': True}, {'player_id': 528612, 'team_id': 4643, 'shirt_number': '19', 'full_name': '김경민', 'full_name_en': 'Gyeongmin Kim', 'initial_position_name': None, 'is_starting': False}, {'player_id': 500116, 'team_id': 4643, 'shirt_number': '21', 'full_name': '박청효', 'full_name_en': 'Cheonghyo Park', 'initial_position_name': None, 'is_starting': False}, {'player_id': 500113, 'team_id': 4643, 'shirt_number': '6', 'full_name': '김이석', 'full_name_en': 'Iseok Kim', 'initial_position_name': 'CAM', 'is_starting': False}, {'player_id': 187794, 'team_id': 4643, 'shirt_number': '34', 'full_name': '송준석', 'full_name_en': 'Junseok Song', 'initial_position_name': 'LB', 'is_starting': True}, {'player_id': 500118, 'team_id': 4643, 'shirt_number': '18', 'full_name': '김강국', 'full_name_en': 'Kangguk Kim', 'initial_position_name': 'CM', 'is_starting': True}, {'player_id': 500119, 'team_id': 4643, 'shirt_number': '30', 'full_name': '신민하', 'full_name_en': 'Minah Shin', 'initial_position_name': 'CB', 'is_starting': False}, {'player_id': 528960, 'team_id': 4643, 'shirt_number': '24', 'full_name': '헨리', 'full_name_en': 'Henry Hore', 'initial_position_name': 'CM', 'is_starting': True}, {'player_id': 83615, 'team_id': 4643, 'shirt_number': '20', 'full_name': '윤석영', 'full_name_en': 'Sukyoung Yun', 'initial_position_name': None, 'is_starting': False}, {'player_id': 343590, 'team_id': 4643, 'shirt_number': '28', 'full_name': '조진혁', 'full_name_en': 'Jinhyuk Cho', 'initial_position_name': 'LB', 'is_starting': False}, {'player_id': 500502, 'team_id': 4643, 'shirt_number': '97', 'full_name': '이유현', 'full_name_en': 'Youhyeon Lee', 'initial_position_name': 'RB', 'is_starting': True}, {'player_id': 85175, 'team_id': 4643, 'shirt_number': '1', 'full_name': '이광연', 'full_name_en': 'Gwangyeon Lee', 'initial_position_name': 'GK', 'is_starting': True}, {'player_id': 500121, 'team_id': 4643, 'shirt_number': '47', 'full_name': '양민혁', 'full_name_en': 'Minhyuk Yang', 'initial_position_name': 'RW', 'is_starting': True}]}
# match_result : {'home_team_score': 4, 'away_team_score': 0}
# fps : 30.0
# ground_width : 99.8
# ground_height : 68

# %%
def create_team_dataframe(home_team_info, away_team_info):
    home_team_rows = []
    base_info = {
            'player': None,
            'position': None,
            'team': 'Home',
            'jID': None,
            'pID': None,
            'tID': home_team_info.get('team_id'),
            'xID': None   
        }
    for idx, player_data in enumerate(home_team_info['players']):
        player_info = base_info.copy()
        player_info['player'] = player_data['full_name_en']
        player_info['position'] = player_data['initial_position_name']
        player_info['jID'] = player_data['shirt_number']
        player_info['pID'] = player_data['player_id']
        player_info['xID'] = idx
        home_team_rows.append(player_info)

    home_df = pd.DataFrame(home_team_rows)

    away_team_rows = []
    base_info['team'] = 'Away'
    base_info['tID'] = away_team_info.get('team_id')
    for idx, player_data in enumerate(away_team_info['players']):
        player_info = base_info.copy()
        player_info['player'] = player_data['full_name_en']
        player_info['position'] = player_data['initial_position_name']
        player_info['jID'] = player_data['shirt_number']
        player_info['pID'] = player_data['player_id']
        player_info['xID'] = idx
        away_team_rows.append(player_info)

    away_df = pd.DataFrame(away_team_rows)

    return {'Home': home_df, 'Away': away_df}

teams_dict = create_team_dataframe(meta_data['home_team'], meta_data['away_team'])

# %%
teams_dict['Home']
# Out:
#                player position  team jID     pID   tID  xID
# 0          Dongwon Ji       CF  Home  10  500530  4220    0
# 1         Ju Yeop Kim     None  Home  24   77715  4220    1
# 2          Taehan Kim       CB  Home  15  500547  4220    2
# 3        Joon Soo Ahn       GK  Home  13  500552  4220    3
# 4        Hyunyong Lee       CB  Home  30  354820  4220    4
# 5      Young Woo Jang     None  Home  26  500540  4220    5
# 6          Gyowon Han       RW  Home  71  532196  4220    6
# 7           Yoonho Jo      RWB  Home   4  500543  4220    7
# 8          Jungwoo Ha     None  Home  39  503230  4220    8
# 9         Minki Jeong     None  Home  99  532195  4220    9
# 10     Seungwon Jeong       CM  Home   7  500534  4220   10
# 11      Seungbae Jung       LW  Home  44  500539  4220   11
# 12      Bitgaram Yoon      CDM  Home  14  354812  4220   12
# 13      Cheolwoo Park       LB  Home   3  354809  4220   13
# 14  Anderson Oliveira       LW  Home  70  500549  4220   14
# 15       Gyeongho Noh       CM  Home  22  529744  4220   15
# 16      Sangyoon Kang       CM  Home  77  500554  4220   16
# 17           Yong Lee       RB  Home  88  287282  4220   17
# 18         Yunho Kwak     None  Home  21  188185  4220   18
# 19      Soonmin Hwang      LWB  Home  20  252492  4220   19

# %%
teams_dict['Away']
# Out:
#               player position  team jID     pID   tID  xID
# 0      Vitor Gabriel       CF  Away  10  412017  4643    0
# 1       Youngbin Kim     None  Away   2  145673  4643    1
# 2   Franko Kovačević       CF  Away   9  529741  4643    2
# 3         Junseo Jin       RB  Away  15  528959  4643    3
# 4         Marko Tuci       CB  Away  74  408792  4643    4
# 5           Insoo Yu       LW  Away  17  343587  4643    5
# 6         Gihyuk Lee       CB  Away  13  500115  4643    6
# 7       Sangheon Lee      CAM  Away  22  500117  4643    7
# 8      Gyeongmin Kim     None  Away  19  528612  4643    8
# 9     Cheonghyo Park     None  Away  21  500116  4643    9
# 10         Iseok Kim      CAM  Away   6  500113  4643   10
# 11      Junseok Song       LB  Away  34  187794  4643   11
# 12       Kangguk Kim       CM  Away  18  500118  4643   12
# 13        Minah Shin       CB  Away  30  500119  4643   13
# 14        Henry Hore       CM  Away  24  528960  4643   14
# 15      Sukyoung Yun     None  Away  20   83615  4643   15
# 16       Jinhyuk Cho       LB  Away  28  343590  4643   16
# 17      Youhyeon Lee       RB  Away  97  500502  4643   17
# 18     Gwangyeon Lee       GK  Away   1   85175  4643   18
# 19      Minhyuk Yang       RW  Away  47  500121  4643   19

# %%
event_data_path = next((f for f in os.listdir(match_path) if "Event" in f), None)
new_path_name = f"{match_id}_event"
if event_data_path and event_data_path != f"{match_id}_event":
    os.rename(f"{match_path}/{event_data_path}", f"{match_path}/{new_path_name}")
else:
    event_data_path = f"{match_path}/{new_path_name}"
print(event_data_path)
# Out:
# /home/work/data/MHL/bepro/153381/153381_event

# %%
event_data_path = f"{match_path}/{match_id}_event"

first_half_event_path =  next((f for f in os.listdir(event_data_path) if "1st" in f), None)
second_half_event_path =  next((f for f in os.listdir(event_data_path) if "2nd" in f), None)

first_half_event_data = load_single_json(f"{event_data_path}/{first_half_event_path}")
second_half_event_data = load_single_json(f"{event_data_path}/{second_half_event_path}")
# Out:
# Successfully loaded file: '/home/work/data/MHL/bepro/153381/153381_event/2024-11-09_SuwonFC vs GangwonFC_1st Half.json'
# Successfully loaded file: '/home/work/data/MHL/bepro/153381/153381_event/2024-11-09_SuwonFC vs GangwonFC_2nd Half.json'

# %%
# Check Event Data

print(first_half_event_data.keys())

first_half_event_df = pd.DataFrame(first_half_event_data['data'])
second_half_event_df = pd.DataFrame(second_half_event_data['data'])

first_half_event_df.head()
# Out:
# dict_keys(['data'])
#   period_type period_name  period_order  period_duration  period_start_time  \
# 0        Half    1st Half             0          2700000                  0
# 1        Half    1st Half             0          2700000                  0
# 2        Half    1st Half             0          2700000                  0
# 3        Half    1st Half             0          2700000                  0
# 4        Half    1st Half             0          2700000                  0
#
#    event_time   team_name player_shirt_number        player_name  \
# 0         600    Suwon FC                  10         Dongwon Ji
# 1        1133    Suwon FC                  70  Anderson Oliveira
# 2        2033  Gangwon FC                  10      Vitor Gabriel
# 3        2700    Suwon FC                  70  Anderson Oliveira
# 4        4067    Suwon FC                  14      Bitgaram Yoon
#
#                                               events       x       y    to_x  \
# 0  [{'event_name': 'Passes', 'property': {'Outcom...  0.4998  0.4996  0.4984
# 1  [{'event_name': 'Passes Received', 'property':...  0.4984  0.5279     NaN
# 2  [{'name': 'VHIR', 'property': {'duration': 500...  0.4981  0.5887  0.5005
# 3  [{'event_name': 'Passes', 'property': {'Outcom...  0.5041  0.5278  0.3257
# 4  [{'event_name': 'Passes Received', 'property':...  0.3257  0.5752     NaN
#
#      to_y attack_direction
# 0  0.5279            RIGHT
# 1     NaN            RIGHT
# 2  0.5421             LEFT
# 3  0.5752            RIGHT
# 4     NaN            RIGHT

# %%
def load_jsonl(file_path):
    """
    Loads data from a JSON Lines (.jsonl) file.

    Each line in the file is expected to be a valid JSON object.
    Lines that are empty or cannot be parsed as JSON will be skipped with a warning.

    Args:
        file_path (str): The path to the .jsonl file.

    Returns:
        list: A list containing the Python objects parsed from each valid JSON line.
              Returns an empty list if the file is not found or contains no valid JSON lines.
    """
    data = [] # To store the parsed JSON objects from each line
    try:
        # Open the file in read mode ('r') with UTF-8 encoding.
        # 'with' ensures the file is closed automatically.
        with open(file_path, 'r', encoding='utf-8') as f:
            # Iterate through each line in the file.
            # enumerate adds line numbers (starting from 1) for better error reporting.
            for line_number, line in enumerate(f, 1):
                # Remove leading/trailing whitespace (including the newline character \n)
                processed_line = line.strip()

                # Skip empty lines
                if not processed_line:
                    continue

                try:
                    # Parse the current line (which is a string) into a Python object.
                    # Use json.loads() for parsing a string, not json.load().
                    parsed_object = json.loads(processed_line)
                    data.append(parsed_object)
                except json.JSONDecodeError:
                    # Handle lines that are not valid JSON.
                    print(f"Warning: Skipping line {line_number} in '{file_path}' due to JSON decoding error.")
                    # Optional: Print the problematic line for debugging
                    # print(f"         Problematic line content: {processed_line[:100]}...")
                except Exception as e:
                    # Handle any other unexpected errors during line processing
                    print(f"Warning: An unexpected error occurred processing line {line_number} in '{file_path}': {e}. Skipping line.")

    except FileNotFoundError:
        # Handle the case where the file itself doesn't exist.
        print(f"Error: File not found at '{file_path}'")
    except Exception as e:
        # Handle other potential errors during file opening or reading (outside the line loop).
        print(f"An error occurred while reading the file '{file_path}': {e}")

    # Return the list of successfully parsed objects.
    return data

# %%
first_half_tracking_data = load_jsonl(f"{match_path}/{match_id}_1_frame_data.jsonl")
second_half_tracking_data = load_jsonl(f"{match_path}/{match_id}_2_frame_data.jsonl")

# %%
print(f"# of frames : {len(first_half_tracking_data)}")
print(f"Keys : {first_half_tracking_data[0].keys()}")
for key in ['period_order', 'match_time', 'frame_index', 'ball_state']:
    print(f"{key} : {first_half_tracking_data[0][key]}")
# Out:
# # of frames : 88226
# Keys : dict_keys(['period_order', 'match_time', 'frame_index', 'ball_state', 'players', 'balls'])
# period_order : 0
# match_time : 0
# frame_index : 0
# ball_state : None

# %%
print(f"# of frames : {len(second_half_tracking_data)}")
print(f"Keys : {second_half_tracking_data[0].keys()}")
for key in ['period_order', 'match_time', 'frame_index', 'ball_state']:
    print(f"{key} : {second_half_tracking_data[0][key]}")
# Out:
# # of frames : 88168
# Keys : dict_keys(['period_order', 'match_time', 'frame_index', 'ball_state', 'players', 'balls'])
# period_order : 1
# match_time : 2700000
# frame_index : 81000
# ball_state : neutral

# %%
for key in ['players', 'balls']:
    print(f"{key} : {len(first_half_tracking_data[0][key])}")
    if len(first_half_tracking_data[0][key]) != 0:
        print(f"{key} : {first_half_tracking_data[0][key][0]}")
# Out:
# players : 21
# players : {'object': 'PLAYER', 'player_id': 85175, 'x': 97.8814, 'y': 32.1887, 'speed': 1.4158}
# balls : 0

# %%
def create_tracking_dataframe(match_path, teams_dict):
    match_id = match_path.split("/")[-1]
    first_half_tracking_data = load_jsonl(f"{match_path}/{match_id}_1_frame_data.jsonl")
    second_half_tracking_data = load_jsonl(f"{match_path}/{match_id}_2_frame_data.jsonl")

    all_object_rows = []

    for half_tracking_data in [first_half_tracking_data, second_half_tracking_data]:
        for frame_data in tqdm(half_tracking_data):
            # Check ball state
            ball_state = frame_data.get('ball_state')
            if ball_state is None or ball_state == 'out':
                new_ball_state = 'dead'
                ball_owning_team_id = None
            else:
                new_ball_state = 'alive'
                if ball_state == 'home':
                    ball_owning_team_id = teams_dict['Home']['tID'].iloc[0]
                elif ball_state == 'away':
                    ball_owning_team_id = teams_dict['Away']['tID'].iloc[0]
                else:
                    ball_owning_team_id = ball_state

            # 2. Extract current frames base information.
            frame_info = {
                'game_id': match_id,
                'period_id': frame_data.get('period_order') + 1,
                'match_time': frame_data.get('match_time'),
                'frame_id': frame_data.get('frame_index'),
                'ball_state': new_ball_state,
                'ball_owning_team_id': ball_owning_team_id,
            }

            for object in ['players', 'balls']:
                object_list = frame_data.get(object, [])
                if object_list:
                    for object_data in object_list:
                        row_data = frame_info.copy()
                        row_data.update(object_data)
                        if object == 'balls':
                            row_data['id'] = 'ball'
                        else:
                            row_data['id'] = row_data['player_id']
                        row_data.pop('object')
                        row_data.pop('player_id')
                        all_object_rows.append(row_data)

    tracking_df = pd.DataFrame(all_object_rows)
    return tracking_df

# %%
tracking_df = create_tracking_dataframe(match_path, teams_dict)
tracking_df.head()
# Out:
# 100%|██████████| 88226/88226 [00:00<00:00, 93460.71it/s]
# 100%|██████████| 88168/88168 [00:00<00:00, 89823.82it/s]
#   game_id  period_id  match_time  frame_id ball_state ball_owning_team_id  \
# 0  153381          1           0         0       dead                None
# 1  153381          1           0         0       dead                None
# 2  153381          1           0         0       dead                None
# 3  153381          1           0         0       dead                None
# 4  153381          1           0         0       dead                None
#
#          x        y   speed      id
# 0  97.8814  32.1887  1.4158   85175
# 1  65.8979  13.9988  0.0627  187794
# 2  31.0232  21.5441  0.8194  287282
# 3  51.1605  14.5683  0.3967  343587
# 4  50.2939  65.4722  0.2310  354809
